# %%
from waybackpy import WaybackMachineSaveAPI

from waybackpy import WaybackMachineCDXServerAPI
url = "https://cs111.wellesley.edu/archive/cs111_fall10/public_html/notes/"
user_agent = "my new app's user agent"
cdx_api = WaybackMachineCDXServerAPI(url, user_agent)

# %%
newest = cdx_api.newest()
newest.timestamp
# Out:
# ---------------------------------------------------------------------------
# NoCDXRecordFound                          Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 newest = cdx_api.newest()
#       2 newest.timestamp
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\waybackpy\cdx_api.py:247, in WaybackMachineCDXServerAPI.newest(self)
#     240 def newest(self) -> CDXSnapshot:
#     241     """
#     242     Passes the current UNIX time to near() for retrieving the newest archive
#     243     from the availability API.
#     244
#     245     Remember UNIX time is UTC and Wayback Machine is also UTC based.
#     246     """
# --> 247     return self.near(unix_timestamp=int(time.time()))
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\waybackpy\cdx_api.py:231, in WaybackMachineCDXServerAPI.near(self, year, month, day, hour, minute, unix_timestamp, wayback_machine_timestamp)
#     228     break
# ...

# %%
pip install trafilatura
# Out:
# ...
#    ---------------------------------------- 0.0/837.9 kB ? eta -:--:--
#    ---------------------------------------- 837.9/837.9 kB 7.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from trafilatura import fetch_url, extract_metadata

download = fetch_url('https://www.bsubears.com/sports/sball/2009-10/files/plyr_3.htm')
metadata = extract_metadata(download)
print(metadata.date)
print(type(metadata.date))
# Out:
# 2019-01-01
# <class 'str'>

# %%
pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------- ----- 1.6/1.8 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 9.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.0
#     Uninstalling pip-25.0:
#       Successfully uninstalled pip-25.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install htmldate
# Out:
# ...
#
# ...

# %%
from htmldate import find_date
find_date('https://www.bsubears.com/sports/sball/2009-10/files/plyr_3.htm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 from htmldate import find_date
# ----> 2 find_date('https://www.bsubears.com/sports/sball/2009-10/files/plyr_3.htm')
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\htmldate\core.py:861, in find_date(htmlobject, extensive_search, original_date, outputformat, url, verbose, min_date, max_date, deferred_url_extractor)
#     858 if verbose:
#     859     logging.basicConfig(level=logging.DEBUG)
# --> 861 tree = load_html(htmlobject)
#     863 # safeguards
#     864 if tree is None:
#
# File c:\Users\diann\AppData\Local\Programs\Python\Python313\Lib\site-packages\htmldate\utils.py:216, in load_html(htmlobject)
#     214     # log the error and quit
#     215     if htmlobject is None:
# --> 216         raise ValueError("URL couldn't be processed: %s", htmlobject)
# ...

# %%
## TESTING DATES FROM BBC

download1 = fetch_url('https://www.bbc.com')
download2 = fetch_url('https://www.bbc.com/future/article/20250516-the-people-stuck-using-ancient-windows-computers')
test1 = extract_metadata(download1)
test2 = extract_metadata(download2)
print(test1.date)
print(test2.date)
# Out:
# 2025-07-17
# 2025-05-18
